# %% [markdown]
# # Introduction

# %% [markdown]
# This is a SQL demo. I will use [pandasql library](https://pypi.org/project/pandasql/) for use sql in pandas.

# %% [markdown]
# So, step one is import or install this library

# %%
import pip
def import_or_install(package):
    try:
        __import__(package)
    except ImportError:
        pip.main(['install', package])       
import_or_install("pandasql")

# %%
from pandasql import PandaSQL
pdsql = PandaSQL()

# %% [markdown]
# Ok, now we need data. We will use one Seaborn dataset, from Titanic survivors.

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Ok, 'head()' function show the first 5 rows (by default), so let doing the same, but with sql query:

# %%
pdsql("SELECT * FROM titanic LIMIT 5;")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man           1  None  Southampton    no      0
# 1  woman           0     C    Cherbourg   yes      0
# 2  woman           0  None  Southampton   yes      1
# 3  woman           0     C  Southampton   yes      0
# 4    man           1  None  Southampton    no      1

# %% [markdown]
# We can, of course, select some condition:

# %%
pdsql("SELECT * FROM titanic WHERE sex='female' LIMIT 5;")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       1  female  38.0      1      0  71.2833        C   First
# 1         1       3  female  26.0      0      0   7.9250        S   Third
# 2         1       1  female  35.0      1      0  53.1000        S   First
# 3         1       3  female  27.0      0      2  11.1333        S   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  deck  embark_town alive  alone
# 0  woman           0     C    Cherbourg   yes      0
# 1  woman           0  None  Southampton   yes      1
# 2  woman           0     C  Southampton   yes      0
# 3  woman           0  None  Southampton   yes      0
# 4  child           0  None    Cherbourg   yes      0

# %% [markdown]
# Given that pdsql return a dataframe, we can use other dataframe functions over it. For simple example, call head with just 2 rows:

# %%
pdsql("SELECT * FROM titanic WHERE sex='female' LIMIT 5;").head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         1       1  female  38.0      1      0  71.2833        C  First
# 1         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male  deck  embark_town alive  alone
# 0  woman           0     C    Cherbourg   yes      0
# 1  woman           0  None  Southampton   yes      1

# %% [markdown]
# ... or tail from the first 5 rows:

# %%
pdsql("SELECT * FROM titanic WHERE sex='female' LIMIT 5;").tail(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 3         1       3  female  27.0      0      2  11.1333        S   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  deck  embark_town alive  alone
# 3  woman           0  None  Southampton   yes      0
# 4  child           0  None    Cherbourg   yes      0

# %% [markdown]
# ## Agregate queries

# %% [markdown]
# Let explore how many people

# %%
query = """
SELECT count(*) AS count, class, sex, who, survived, count(survived) as count_survived
FROM titanic
GROUP BY class, sex, who, survived
ORDER BY class, sex, who DESC
"""
pdsql(query)
# Out:
#     count   class     sex    who  survived  count_survived
# 0       2   First  female  woman         0               2
# 1      89   First  female  woman         1              89
# 2       1   First  female  child         0               1
# 3       2   First  female  child         1               2
# 4      77   First    male    man         0              77
# 5      42   First    male    man         1              42
# 6       3   First    male  child         1               3
# 7       6  Second  female  woman         0               6
# 8      60  Second  female  woman         1              60
# 9      10  Second  female  child         1              10
# 10     91  Second    male    man         0              91
# 11      8  Second    male    man         1               8
# 12      9  Second    male  child         1               9
# 13     58   Third  female  woman         0              58
# 14     56   Third  female  woman         1              56
# 15     14   Third  female  child         0              14
# 16     16   Third  female  child         1              16
# 17    281   Third    male    man         0             281
# 18     38   Third    male    man         1              38
# 19     19   Third    male  child         0              19
# 20      9   Third    male  child         1               9

# %%
query = """
SELECT count(*) AS count, class, sex, who, survived, count(survived) as count_survived
FROM titanic
GROUP BY class, sex, who, survived
HAVING (survived)>0
ORDER BY class, sex, who DESC
"""
survived = pdsql(query)
survived
# Out:
#     count   class     sex    who  survived  count_survived
# 0      89   First  female  woman         1              89
# 1       2   First  female  child         1               2
# 2      42   First    male    man         1              42
# 3       3   First    male  child         1               3
# 4      60  Second  female  woman         1              60
# 5      10  Second  female  child         1              10
# 6       8  Second    male    man         1               8
# 7       9  Second    male  child         1               9
# 8      56   Third  female  woman         1              56
# 9      16   Third  female  child         1              16
# 10     38   Third    male    man         1              38
# 11      9   Third    male  child         1               9

# %% [markdown]
# Ok, let check if that is correct: we have a dataframe, called 'survived' with agregational data. We can use '<>column.sum()' to sum all element in that column:

# %%
survived.count_survived.sum()
# Out:
# 342

# %% [markdown]
# We can see that it the same with the simple query

# %%
query = """
SELECT count(*)
FROM titanic
WHERE (survived)>0
ORDER BY class, sex, who DESC
"""
pdsql(query)
# Out:
#    count(*)
# 0       342

# %% [markdown]
# ## Separate classes

# %%
query = """
SELECT *
FROM titanic
WHERE class='First'
"""
c1 = pdsql(query)
c1
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0           1       1  female  38.0      1      0   71.2833        C  First
# 1           1       1  female  35.0      1      0   53.1000        S  First
# 2           0       1    male  54.0      0      0   51.8625        S  First
# 3           1       1  female  58.0      0      0   26.5500        S  First
# 4           1       1    male  28.0      0      0   35.5000        S  First
# 5           0       1    male  19.0      3      2  263.0000        S  First
# 6           0       1    male  40.0      0      0   27.7208        C  First
# 7           1       1  female   NaN      1      0  146.5208        C  First
# 8           0       1    male  28.0      1      0   82.1708        C  First
# 9           0       1    male  42.0      1      0   52.0000        S  First
# 10          1       1  female  49.0      1      0   76.7292        C  First
# 11          0       1    male  65.0      0      1   61.9792        C  First
# 12          1       1    male   NaN      0      0   35.5000        S  First
# 13          1       1  female  38.0      0      0   80.0000     None  First
# 14          0       1    male  45.0      1      0   83.4750        S  First
# 15          0       1    male   NaN      0      0   27.7208        C  First
# 16          0       1    male  28.0      0      0   47.1000        S  First
# 17          1       1  female  23.0      3      2  263.0000        S  First
# 18          0       1    male  46.0      1      0   61.1750        S  First
# 19          0       1    male  71.0      0      0   34.6542        C  First
# 20          1       1    male  23.0      0      1   63.3583        C  First
# 21          0       1    male  21.0      0      1   77.2875        S  First
# 22          0       1    male  47.0      0      0   52.0000        S  First
# 23          0       1    male  24.0      0      1  247.5208        C  First
# 24          0       1    male  54.0      0      1   77.2875        S  First
# 25          1       1  female  19.0      0      2   26.2833        S  First
# 26          0       1    male  37.0      1      0   53.1000        S  First
# 27          0       1    male  24.0      0      0   79.2000        C  First
# 28          1       1  female  22.0      1      0   66.6000        S  First
# 29          0       1    male  51.0      0      1   61.3792        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 186         1       1  female  36.0      1      2  120.0000        S  First
# 187         1       1  female  51.0      1      0   77.9583        S  First
# 188         0       1    male   NaN      0      0   39.6000        C  First
# 189         1       1  female  43.0      0      1  211.3375        S  First
# 190         1       1  female  17.0      1      0   57.0000        S  First
# 191         0       1    male  29.0      0      0   30.0000        S  First
# 192         0       1    male  46.0      0      0   79.2000        C  First
# 193         0       1    male   NaN      0      0   30.6958        C  First
# 194         1       1  female  49.0      0      0   25.9292        S  First
# 195         1       1    male  11.0      1      2  120.0000        S  First
# 196         0       1    male  39.0      0      0    0.0000        S  First
# 197         1       1  female  33.0      1      0   53.1000        S  First
# 198         0       1    male   NaN      0      0    0.0000        S  First
# 199         1       1  female  52.0      1      1   93.5000        S  First
# 200         0       1    male  38.0      0      0    0.0000        S  First
# 201         1       1  female  62.0      0      0   80.0000     None  First
# 202         1       1  female  39.0      1      1   83.1583        C  First
# 203         1       1    male   NaN      0      0   29.7000        C  First
# 204         1       1  female  30.0      0      0   31.0000        C  First
# 205         1       1  female   NaN      1      0   89.1042        C  First
# 206         1       1  female  16.0      0      1   39.4000        S  First
# 207         1       1  female  45.0      1      1  164.8667        S  First
# 208         1       1    male  51.0      0      0   26.5500        S  First
# 209         1       1  female  48.0      0      0   25.9292        S  First
# 210         0       1    male  31.0      0      0   50.4958        S  First
# 211         1       1  female  47.0      1      1   52.5542        S  First
# 212         0       1    male  33.0      0      0    5.0000        S  First
# 213         1       1  female  56.0      0      1   83.1583        C  First
# 214         1       1  female  19.0      0      0   30.0000        S  First
# 215         1       1    male  26.0      0      0   30.0000        C  First
#
#        who  adult_male  deck  embark_town alive  alone
# 0    woman           0     C    Cherbourg   yes      0
# 1    woman           0     C  Southampton   yes      0
# 2      man           1     E  Southampton    no      1
# 3    woman           0     C  Southampton   yes      1
# 4      man           1     A  Southampton   yes      1
# 5      man           1     C  Southampton    no      0
# 6      man           1  None    Cherbourg    no      1
# 7    woman           0     B    Cherbourg   yes      0
# 8      man           1  None    Cherbourg    no      0
# 9      man           1  None  Southampton    no      0
# 10   woman           0     D    Cherbourg   yes      0
# 11     man           1     B    Cherbourg    no      0
# 12     man           1     C  Southampton   yes      1
# 13   woman           0     B         None   yes      1
# 14     man           1     C  Southampton    no      0
# 15     man           1  None    Cherbourg    no      1
# 16     man           1  None  Southampton    no      1
# 17   woman           0     C  Southampton   yes      0
# 18     man           1     E  Southampton    no      0
# 19     man           1     A    Cherbourg    no      1
# 20     man           1     D    Cherbourg   yes      0
# 21     man           1     D  Southampton    no      0
# 22     man           1     C  Southampton    no      1
# 23     man           1     B    Cherbourg    no      0
# 24     man           1     D  Southampton    no      0
# 25   woman           0     D  Southampton   yes      0
# 26     man           1     C  Southampton    no      0
# 27     man           1     B    Cherbourg    no      1
# 28   woman           0     C  Southampton   yes      0
# 29     man           1  None    Cherbourg    no      0
# ..     ...         ...   ...          ...   ...    ...
# 186  woman           0     B  Southampton   yes      0
# 187  woman           0     D  Southampton   yes      0
# 188    man           1  None    Cherbourg    no      1
# 189  woman           0     B  Southampton   yes      0
# 190  woman           0     B  Southampton   yes      0
# 191    man           1     D  Southampton    no      1
# 192    man           1     B    Cherbourg    no      1
# 193    man           1  None    Cherbourg    no      1
# 194  woman           0     D  Southampton   yes      1
# 195  child           0     B  Southampton   yes      0
# 196    man           1     A  Southampton    no      1
# 197  woman           0     E  Southampton   yes      0
# 198    man           1     B  Southampton    no      1
# 199  woman           0     B  Southampton   yes      0
# 200    man           1  None  Southampton    no      1
# 201  woman           0     B         None   yes      1
# 202  woman           0     E    Cherbourg   yes      0
# 203    man           1     C    Cherbourg   yes      1
# 204  woman           0  None    Cherbourg   yes      1
# 205  woman           0     C    Cherbourg   yes      0
# 206  woman           0     D  Southampton   yes      0
# 207  woman           0  None  Southampton   yes      0
# 208    man           1     E  Southampton   yes      1
# 209  woman           0     D  Southampton   yes      1
# 210    man           1     A  Southampton    no      1
# 211  woman           0     D  Southampton   yes      0
# 212    man           1     B  Southampton    no      1
# 213  woman           0     C    Cherbourg   yes      0
# 214  woman           0     B  Southampton   yes      1
# 215    man           1     C    Cherbourg   yes      1
#
# [216 rows x 15 columns]

# %%
query = """
SELECT *
FROM titanic
WHERE class='Second'
"""
c2 = pdsql(query)
c2
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 0           1       2  female  14.00      1      0  30.0708        C  Second
# 1           1       2  female  55.00      0      0  16.0000        S  Second
# 2           1       2    male    NaN      0      0  13.0000        S  Second
# 3           0       2    male  35.00      0      0  26.0000        S  Second
# 4           1       2    male  34.00      0      0  13.0000        S  Second
# 5           0       2    male  66.00      0      0  10.5000        S  Second
# 6           0       2  female  27.00      1      0  21.0000        S  Second
# 7           1       2  female   3.00      1      2  41.5792        C  Second
# 8           1       2  female  29.00      1      0  26.0000        S  Second
# 9           1       2  female  21.00      0      0  10.5000        S  Second
# 10          1       2  female   5.00      1      2  27.7500        S  Second
# 11          1       2  female  29.00      0      0  10.5000        S  Second
# 12          0       2    male  32.00      0      0  10.5000        S  Second
# 13          0       2    male  21.00      0      0  73.5000        S  Second
# 14          1       2    male   0.83      0      2  29.0000        S  Second
# 15          1       2  female  17.00      0      0  10.5000        S  Second
# 16          1       2  female  34.00      0      1  23.0000        S  Second
# 17          0       2    male  34.00      1      0  26.0000        S  Second
# 18          0       2    male  29.00      1      0  21.0000        S  Second
# 19          0       2    male  21.00      2      0  73.5000        S  Second
# 20          0       2    male  32.50      1      0  30.0708        C  Second
# 21          1       2  female  32.50      0      0  13.0000        S  Second
# 18     man           1  None  Southampton    no      0
# 19     man           1  None  Southampton    no      0
# 20     man           1  None    Cherbourg    no      0
# 21   woman           0     E  Southampton   yes      1
# 22   woman           0  None  Southampton   yes      0
# 23     man           1  None  Southampton    no      1
# 24     man           1  None    Cherbourg    no      1
# 25     man           1  None  Southampton    no      1
# 26     man           1  None  Southampton    no      0
# 27     man           1     F  Southampton    no      0
# 28     man           1  None  Southampton    no      1
# 29     man           1  None  Southampton    no      1
# ..     ...         ...   ...          ...   ...    ...
# 154    man           1  None  Southampton    no      1
# 155    man           1  None  Southampton    no      1
# 156    man           1  None  Southampton    no      1
# 157  woman           0  None  Southampton   yes      1
# 158  child           0  None  Southampton   yes      0
# 159  woman           0  None  Southampton   yes      0
# 160  child           0  None  Southampton   yes      0
# 161    man           1  None  Southampton    no      1
# 162  woman           0     E  Southampton    no      1
# 163  woman           0  None  Southampton   yes      0
# 164    man           1  None  Southampton    no      1
# 165    man           1  None  Southampton    no      1
# 166    man           1  None  Southampton    no      1
# 167  woman           0  None  Southampton   yes      0
# 168    man           1  None  Southampton    no      1
# 169    man           1  None  Southampton    no      1
# 170    man           1  None    Cherbourg    no      0
# 171  child           0  None    Cherbourg   yes      0
# 172  child           0  None  Southampton   yes      0
# 173    man           1  None  Southampton    no      1
# 174    man           1  None  Southampton    no      0
# 175  woman           0  None  Southampton    no      0
# 176    man           1  None  Southampton    no      0
# 177    man           1  None  Southampton    no      1
# 178  woman           0  None  Southampton   yes      1
# 179  woman           0  None    Cherbourg   yes      0
# 180  woman           0  None    Cherbourg   yes      0
# 181  woman           0  None  Southampton   yes      0
# 182    man           1  None  Southampton    no      1
# 183    man           1  None  Southampton    no      1
#
# [184 rows x 15 columns]

# %%
query = """
SELECT *
FROM titanic
WHERE class='Third'
"""
c3 = pdsql(query)
c3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       3  female  26.0      0      0   7.9250        S  Third
# 2           0       3    male  35.0      0      0   8.0500        S  Third
# 3           0       3    male   NaN      0      0   8.4583        Q  Third
# 4           0       3    male   2.0      3      1  21.0750        S  Third
# 5           1       3  female  27.0      0      2  11.1333        S  Third
# 6           1       3  female   4.0      1      1  16.7000        S  Third
# 7           0       3    male  20.0      0      0   8.0500        S  Third
# 8           0       3    male  39.0      1      5  31.2750        S  Third
# 9           0       3  female  14.0      0      0   7.8542        S  Third
# 10          0       3    male   2.0      4      1  29.1250        Q  Third
# 11          0       3  female  31.0      1      0  18.0000        S  Third
# 12          1       3  female   NaN      0      0   7.2250        C  Third
# 13          1       3  female  15.0      0      0   8.0292        Q  Third
# 14          0       3  female   8.0      3      1  21.0750        S  Third
# 15          1       3  female  38.0      1      5  31.3875        S  Third
# 16          0       3    male   NaN      0      0   7.2250        C  Third
# 17          1       3  female   NaN      0      0   7.8792        Q  Third
# 18          0       3    male   NaN      0      0   7.8958        S  Third
# 19          1       3  female   NaN      0      0   7.7500        Q  Third
# 17   woman           0  None   Queenstown   yes      1
# 18     man           1  None  Southampton    no      1
# 19   woman           0  None   Queenstown   yes      1
# 20     man           1  None    Cherbourg   yes      1
# 21     man           1  None  Southampton    no      1
# 22   woman           0  None  Southampton    no      0
# 23   child           0  None    Cherbourg   yes      0
# 24   woman           0  None  Southampton    no      0
# 25     man           1  None    Cherbourg    no      1
# 26   woman           0  None   Queenstown   yes      1
# 27     man           1  None  Southampton    no      1
# 28     man           1  None   Queenstown    no      0
# 29   woman           0  None   Queenstown   yes      1
# ..     ...         ...   ...          ...   ...    ...
# 461    man           1  None  Southampton    no      1
# 462    man           1  None  Southampton   yes      1
# 463    man           1  None  Southampton    no      1
# 464    man           1  None    Cherbourg    no      1
# 465    man           1  None  Southampton    no      1
# 466    man           1  None  Southampton    no      1
# 467    man           1  None  Southampton    no      0
# 468    man           1  None    Cherbourg    no      1
# 469  child           0  None  Southampton    no      0
# 470    man           1  None  Southampton    no      1
# 471  child           0  None    Cherbourg    no      0
# 472  woman           0  None  Southampton   yes      0
# 473  woman           0  None    Cherbourg   yes      0
# 474    man           1  None    Cherbourg    no      1
# 475    man           1  None  Southampton    no      0
# 476  woman           0  None  Southampton    no      0
# 477    man           1  None  Southampton    no      1
# 478  child           0  None  Southampton   yes      0
# 479    man           1  None  Southampton    no      1
# 480    man           1  None  Southampton    no      1
# 481  child           0  None    Cherbourg   yes      1
# 482    man           1  None  Southampton    no      1
# 483    man           1  None  Southampton    no      1
# 484    man           1  None  Southampton    no      1
# 485    man           1  None  Southampton    no      1
# 486  woman           0  None  Southampton    no      1
# 487    man           1  None  Southampton    no      1
# 488  woman           0  None   Queenstown    no      0
# 489  woman           0  None  Southampton    no      0
# 490    man           1  None   Queenstown    no      1
#
# [491 rows x 15 columns]

# %% [markdown]
# ### There is some 'embark_town' common in c1 and c2?

# %%
query = """
SELECT DISTINCT c1.embark_town
FROM c1, c2
WHERE c1.embark_town = c2.embark_town
--LIMIT 2
"""
pdsql(query)
# Out:
#    embark_town
# 0    Cherbourg
# 1  Southampton
# 2   Queenstown

# %% [markdown]
# ### There is some 'embark_town' common in c1, c2 and c3?

# %%
query = """
SELECT DISTINCT c1.embark_town
FROM c1, c2, c3
WHERE 
c1.embark_town = c2.embark_town and
c2.embark_town = c3.embark_town 
--LIMIT 2
"""
pdsql(query)
# Out:
#    embark_town
# 0    Cherbourg
# 1  Southampton
# 2   Queenstown

# %% [markdown]
# Just for check, let see the shared from c1 and c3...

# %%
query = """
SELECT DISTINCT c1.embark_town
FROM c1, c3
WHERE c1.embark_town = c3.embark_town
"""
pdsql(query)
# Out:
#    embark_town
# 0    Cherbourg
# 1  Southampton
# 2   Queenstown

# %% [markdown]
# Yes, the 3 classes have 'embark_town' in Cherbourg, Southampton and Queenstown.

# %% [markdown]
# # [See the interactive version](https://nbviewer.jupyter.org/github/NeoRichard/DemoSQL/blob/master/DemoSQL1.ipynb)
